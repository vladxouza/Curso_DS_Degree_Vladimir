# %% [markdown]
# # Aula 4 - strings
#
# Na aula de hoje, vamos explorar os seguintes tópicos em Python:
#
# - 1) Strings
# - 2) Funções de Strings
#     - 2.1) Formatação de strings
# _______
#
# ### Objetivos
#
# Apresentar o conceito de strings de forma mais aprofundada, como uma coleção de caracteres, fazendo a ligação com o conceito de listas, que já foi estudado, mostrando as semelhanças e diferenças. Depois, apresentar as principais funções e métodos que atuam sobre strings, frisando a importância de utilizá-las no pré-processamento de dados textuais.
#
# ### Habilidades a serem desenvolvidas
#
# Ao final da aula o aluno deve:
#
# - Reconhecer strings como coleções de caracteres;
# - Saber acessar elementos individuas e slices de strings;
# - Saber iterar sobre strings;
# - Conhecer os principais métodos e funções que atuam sobre strings;
# - Entender a importância de processar strings;
# - Saber formatar strings com o `format()`

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 1) Strings
#
# Desde a primeira aula, temos trabalhado com strings, que, como vimos, representam **dados textuais**
#
# Vamos, agora, olhar pra strings um pouco mais a fundo, e aprender algumas funções para trabalharmos com strings

# %% [markdown]
# Uma string nada mais é do que uma **coleção de caracteres**!
#
# Assim, podemos acessar caracteres específicos ou então um intervalo de caracteres de uma string, como se fosse uma lista!
#
# **OBS.: Para strings também, o índice começa em 0, e podemos usar índices negativos!**

# %%
palavra = 'banana'
type(palavra)
# Out:
# str

# %%
palavra[-2]
# Out:
# 'n'

# %%
palavra[0]
# Out:
# 'b'

# %% [markdown]
# Para saber o comprimento de uma string (quantos caracteres ela tem, incluindo espaços e pontuações), use a função len():

# %%
len(palavra)
# Out:
# 6

# %% [markdown]
# Podemos também percorrer cada caractere da string com o `for` -- strings são objetos **iteráveis**:

# %%
for char in palavra:
    print(char)
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# Dá pra fazer o mesmo com o len():

# %%
# %%time
i = 0
palavra = 'bananaasdjaskdjalsdjaljdakjdalksjdlasjdlajsdlajsdjalsd'

while i < len(palavra):
    print(f'letra é igual a {palavra[i]}')
    # i = i + 1
    i += 1
    
print('Fim')
# Out:
# letra é igual a b
# letra é igual a a
# letra é igual a n
# letra é igual a a
# letra é igual a n
# letra é igual a a
# letra é igual a a
# letra é igual a s
# letra é igual a d
# letra é igual a j
# letra é igual a a
# letra é igual a s
# letra é igual a k
# letra é igual a d
# letra é igual a j
# letra é igual a a
# letra é igual a l
# letra é igual a s
# letra é igual a d
# letra é igual a j
# letra é igual a a
# letra é igual a l
# letra é igual a j
# letra é igual a d
# letra é igual a a
# letra é igual a k
# letra é igual a j
# letra é igual a d
# letra é igual a a
# letra é igual a l
# letra é igual a k
# letra é igual a s
# letra é igual a j
# letra é igual a d
# letra é igual a l
# letra é igual a a
# letra é igual a s
# letra é igual a j
# letra é igual a d
# letra é igual a l
# letra é igual a a
# letra é igual a j
# letra é igual a s
# letra é igual a d
# letra é igual a l
# letra é igual a a
# letra é igual a j
# letra é igual a s
# letra é igual a d
# letra é igual a j
# letra é igual a a
# letra é igual a l
# letra é igual a s
# letra é igual a d
# Fim
# Wall time: 4.99 ms

# %% [markdown]
# Apesar de se parecer com uma lista, a string não tem exatamente as propriedades de uma lista. Por exemplo, **não podemos alterar** caracteres individualmente:

# %%
lista = [1, 2, 3, 4]
lista[0] = 1000

print(lista)
# Out:
# [1000, 2, 3, 4]

# %%
palavra_nova = 'garrafa'

palavra_nova[3] = 'e'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11812/612310668.py in <module>
#       1 palavra_nova = 'garrafa'
#       2
# ----> 3 palavra_nova[3] = 'e'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Mas nós conseguimos **alterar caracteres (ou palavras)** com o método "replace()":

# %%
palavra_nova = 'garrafa'

palavra_nova.replace('a', 'e')
# Out:
# 'gerrefe'

# %%
palavra_nova2 = 'garrafarr'

palavra_nova2.replace('rr', 's')
# Out:
# 'gasafas'

# %% [markdown]
# Podemos **transformar uma string em uma lista de caracteres**, explicitamente, usando a fução "list()"

# %%
palavra_para_lista = 'akjsdhkajshd'

lista_da_palavra = list(palavra_para_lista)

# %% [markdown]
# Agora sim, podemos alterar um elemento da lista:

# %%
lista_da_palavra[4] = 'P'

# %%
print(lista_da_palavra)
# Out:
# ['a', 'k', 'j', 's', 'P', 'h', 'k', 'a', 'j', 's', 'h', 'd']

# %% [markdown]
# E, pra transformar a lista de volta pra string, usamos a função "join()":

# %%
''.join(lista_da_palavra)
# Out:
# 'akjsPhkajshd'

# %%
variavel = '*'.join(lista_da_palavra)
# Out:
# 'a*k*j*s*P*h*k*a*j*s*h*d'

# %%
' '.join(lista_da_palavra)
# Out:
# 'a k j s P h k a j s h d'

# %%
# Out:
# ['a', 'k', 'j', 's', 'P', 'h', 'k', 'a', 'j', 's', 'h', 'd']

# %% [markdown]
# Um exemplo do uso do .join() pra juntar os números de uma lista em um único numero

# %%
lista_numeros = ['1', '2', '3', '4', '5']

int(''.join(lista_numeros))
# Out:
# 12345

# %%
lista_inteiros = [1, 2, 3, 4, 5]

''.join(lista_inteiros)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11812/1465119951.py in <module>
#       1 lista_inteiros = [1, 2, 3, 4, 5]
#       2
# ----> 3 ''.join(lista_inteiros)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
lista_inteiros = [1, 2, 3, 4, 5]
str(lista_inteiros).replace('[', '').replace(']', '').replace(', ', '')
# Out:
# '12345'

# %%
lista_int = [1, 2, 3, 4, 5]
lista_char = []
for numeros in lista_int:
    lista_char.append(str(numeros))

numero_todo = int(''.join(lista_char))
print(numero_todo)
# Out:
# 12345

# %%
lista = [1, 2, 3, 4, 5, 6]
lista2 = [str(x) for x in lista]
lista3 = int("".join(lista2))
lista3
# Out:
# 123456

# %% [markdown]
# Como já vimos, podemos fazer **operações com strings**:

# %% [markdown]
# Soma de strings: ao somar duas strings, elas são concatenadas:

# %%
['a', 'b', 'c'] + [1, 2, 3]
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
'oi ' + 'Fernanda'
# Out:
# 'oi Fernanda'

# %% [markdown]
# Multiplicação de string por inteiro: ao multiplicar uma string por um número inteiro, a string é repetida:

# %%
[1, 2, 3] * 2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
'Fer' * 5
# Out:
# 'FerFerFerFerFer'

# %%
'Fer' * 'oi'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11812/2434401734.py in <module>
# ----> 1 'Fer' * 'oi'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
'Fer' * len('Fer')
# Out:
# 'FerFerFer'

# %% [markdown]
# __________
# __________
# __________

# %% [markdown]
# ## 2) Funções de strings
#
# Como listas, strings também têm algumas funções específicas. Algumas delas são:

# %% [markdown]
# .upper(): transforma todos os caracteres em maiúscula

# %%
'fernanda'.upper()
# Out:
# 'FERNANDA'

# %%
'oi'.upper()
# Out:
# 'OI'

# %% [markdown]
# .lower(): trasnforma todos os caracteres em minúscula

# %%
'PYTHON'.lower()
# Out:
# 'python'

# %%
'PyThOn'.lower()
# Out:
# 'python'

# %%
palavra_minusculo = input('De seu nome').lower
# Out:
# De seu nomeLucas

# %%
print(palavra_minusculo)
# Out:
# 1

# %%
variavel = input('De uma fruta').lower()
'banana' == variavel
# Out:
# De uma frutaBANANA
# True

# %% [markdown]
# .title(): deixa a primeira letra de cada palavra em maiúscula

# %%
'fernanda namie takemoto furukita'.title()
# Out:
# 'Fernanda Namie Takemoto Furukita'

# %% [markdown]
# .capitalize(): deixa a primeira letra da primeira palavra em maiúscula

# %%
'de volta para o futuro'.capitalize()
# Out:
# 'De volta para o futuro'

# %% [markdown]
# É possível quebrar uma string em determinado caractere, tendo como resultado uma **lista com os caracteres além da quebra**.
#
# - Para quebrar nos espaços, use a função ".split()", sem argumento

# %%
'laranja, banana, maca, melancia'.split(', ')
# Out:
# ['laranja', 'banana', 'maca', 'melancia']

# %%
'laranja, banana, maca, melancia'.split()
# Out:
# ['laranja,', 'banana,', 'maca,', 'melancia']

# %%
'laranja,banana,maca,melancia'.split(',')
# Out:
# ['laranja', 'banana', 'maca', 'melancia']

# %% [markdown]
# - Para quebrar em algum caracter, use o caractere como argumento:

# %%
'laranja,banana,maca,melancia'.split('a')
# Out:
# ['l', 'r', 'nj', ',b', 'n', 'n', ',m', 'c', ',mel', 'nci', '']

# %% [markdown]
# __Tirar espaços que tão sobrando no fim e no início da string__
#
# Utilize a função strip()

# %%
'      Fernanda      '.strip()
# Out:
# 'Fernanda'

# %% [markdown]
# Mas essa função não elimina espaços extrar no "meio" da string -- apenas no início e no fim!

# %%
'      Fern  anda      '.strip()
# Out:
# 'Fern  anda'

# %% [markdown]
# __Pra tirar espaços do meio, podemos fazer:__

# %%
meu_nome = 'Fernanda         Namie        Takemoto        Furukita'

# %%
meu_nome = meu_nome.split()
print(meu_nome)
# Out:
# ['Fernanda', 'Namie', 'Takemoto', 'Furukita']

# %%
meu_nome = ' '.join(meu_nome)
print(meu_nome)
# Out:
# Fernanda Namie Takemoto Furukita

# %%
meu_nome2 = 'Fernanda         Namie        Takemoto        Furukita'

# %%
meu_nome2.replace(' ', '')
# Out:
# 'FernandaNamieTakemotoFurukita'

# %%
lista = [1, 2, 3]

dir(lista)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# Outras funções interessantes...
#
# - isdigit()
# - isalpha()
# - isalnum()
# - isspace()
# - isupper()

# %%
'12345'.isdigit()
# Out:
# True

# %%
numero = 1.56

numero.isdigit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11812/463668047.py in <module>
#       1 numero = 1.56
#       2
# ----> 3 numero.isdigit()
#
# AttributeError: 'float' object has no attribute 'isdigit'

# %%
'12345.5'.isdigit()
# Out:
# False

# %%
'asdlkjKJASDH'.isalpha()
# Out:
# True

# %%
'asdlkjKJASDH2'.isalpha()
# Out:
# False

# %%
'asdlkjKJASDH2'.isalnum()
# Out:
# True

# %%
'asdlkjKJASDH2'.isalnum()
# Out:
# False

# %%
'2 5'.isalnum()
# Out:
# False

# %%
'     '.isspace()
# Out:
# True

# %%
'     B'.isspace()
# Out:
# False

# %%
'AKJSDHKA'.isupper()
# Out:
# True

# %%
'AKSJDHp'.isupper()
# Out:
# False

# %%
'asdkjhp'.islower()
# Out:
# True

# %%
punctuation = ['?', '!', '.', ',']

'.' in punctuation
# Out:
# True

# %% [markdown]
# **Exercício**: Fazer um programa que pega uma frase e separa os caracteres em tres listas, uma só com letras, um só com digitos, e outro com o resto (como pontuações)
#
# dica:
# ```
#
# frase = ...
#
# num = []
#
# letra = []
#
# outros = []
#
# iniciar um loop para iterar por todos os caracteres da frase
# dentro do loop, checar se o caracter é um digito, uma alphabetico ou outro
# em função do tipo do caracter, jogar o caractere em uma das listas novas
# ```
#
# Exemplo:
# ```
# in: frase = "ele disse: vamos nos encontrar às 13:00"
#
# out:
# ['1', '3', '0', '0']
# ['e', 'l', 'e', 'd', 'i', 's', 's', 'e', 'v', 'a', 'm', 'o', 's', 'n', 'o', 's', 'e', 'n', 'c', 'o', 'n', 't', 'r', 'a', 'r', 'à', 's']
# [' ', ':', ' ', ' ', ' ', ' ', ' ', ':']
# ```

# %%
frase=input('Insira uma frase: ')
nums=[]
letras=[]
outros=[]

for i in frase:
    if i.isdigit():
        nums.append(i)
    elif i.isalpha():
        letras.append(i)
    else:
        outros.append(i)
        
print(nums)
print(letras)
print(outros)
# Out:
# Insira uma frase: ele disse: vamos nos encontrar às 13:00
# ['1', '3', '0', '0']
# ['e', 'l', 'e', 'd', 'i', 's', 's', 'e', 'v', 'a', 'm', 'o', 's', 'n', 'o', 's', 'e', 'n', 'c', 'o', 'n', 't', 'r', 'a', 'r', 'à', 's']
# [' ', ':', ' ', ' ', ' ', ' ', ' ', ':']

# %%
palavra = 'oie tudo bem'

for char in palavra:
    print(char)
# Out:
# o
# i
# e
#
# t
# u
# d
# o
#
# b
# e
# m

# %%
lista = ['banana', 'maca']

for char in lista:
    print(char)
# Out:
# banana
# maca

# %% [markdown]
# ___
# ___

# %% [markdown]
# ### 2.1) Formatação de strings
#
# Também podemos **formatar strings**. Isso pode ser super útil tanto ao receber dados do usuário (input) quando ao exbibir dados pro usuário (print)

# %% [markdown]
# Um dos usos mais legal do format é para **exibir** strings formatadas.
#
# Imagine que você queira exibir uma data no formato dd/mm/aaaa.
#
# Em situações normais, dias e meses inferiores a 10 apareceriam com apenas 1 dígito (int não é representado com zeros à esquerda). Porém, podemos especificar no format que gostaríamos de representar um inteiro com 2 dígitos, preenchendo com zero dígitos em branco (à esquerda):
#
# ```python
#
# dia = 1
# mes = 2
# ano = 2020
# data = f'{:02d}/{:02d}/{:04d}'
# print(data) # resultado: 01/02/2020
# ```
#
# O símbolo 'd' indica que estamos representando números **inteiros** em base decimal (dígitos de 0 a 9).
#
# Os símbolos '2' e '4' indicam, respectivamente, 2 dígitos ou 4 dígitos.
#
# o símbolo '0' indica que se faltar dígitos, os espaços devem ser preenchidos com zero

# %%
dia = 1
mes = 2
ano = 2020
print(f'{dia}/{mes}/{ano}')
# Out:
# 1/2/2020

# %%
dia = 1
mes = 2
ano = 2020
data = f'{dia:02d}/{mes:02d}/{ano:04d}'
print(data) # resultado: 01/02/2020
# Out:
# 01/02/2020

# %% [markdown]
# Imagina que você queira exibir algum valor monetário, por exemplo, o preço de alguma coisa.
#
# Utilizando float, pode ser que seu resultado tenha apenas uma casa decimal.
#
# Mas, se tratando de dinheito, sempre queremos mostrar duas casas decimais!
#
# Usaremos o format para representar com apenas 2 casas.
#
# ```python
# preco = 1500.5
#
# print(preco)
#
# precoFinal = f'R$ {preco:.2f}'
#
# print(precoFinal)
# ```
#
# Neste caso, o 'f' indica que o número é float.
#
# Já o '.2' indica que queremos 2 casas após o ponto decimal.
#
# Note que a função não apenas descarta as casas excedentes, e sim arredonda corretamente o número.

# %%
preco = 1500.5

print(preco) 

precoFinal = f'R$ {preco:.2f}'

print(precoFinal)
# Out:
# 1500.5
# R$ 1500.50

# %%
valor_quebrado = 156.9999999

print(f'{valor_quebrado:.3f}')
# Out:
# 157.000

# %%
valor_string = list(str(valor_quebrado))
valor_string
# Out:
# ['1', '5', '6', '.', '9', '9', '9', '9', '9', '9', '9']

# %% [markdown]
# ## Exercícios de Python
#
# **Tópico(s):** String, Função
#
# **Nível**: médio
#
#
# ### Cifra de César símples
#
# Quando falamos de segurança da informação, a criptografia vem logo à mente. Se trata da codificação de mensagens para impedir a leitura por receptores indesejados. A Cifra de César é um dos métodos mais simples e conhecidos da criptografia. Nela, uma letra da mensagem é substituida por outra que se encontra um número fixo de posições em relação ao alfabeto.
#
# Ex.: Se o número fixo (chave) é 3, a letra A seria trocada por D, B por E e assim por diante.
#
# Implemente, usando os conceitos de String em Python, a Cifra de César.
#
# *Exemplo 1, com shift 1*: "Ola mundo" -> 'Pmb!nvoep'
#
# *Exemplo 2, com shift 2*: "Ola mundo" -> 'Qnc"owpfq'
#
# *Exemplo 3, com shift 1*: "zebra" -> '{fcsb'
#
# *Dicas*: use as funções chr() e ord() e o código ASCII.

# %%
import random
shift = random.randint(1,3)
print(shift)
# Out:
# 3

# %%
frase = input('Digite a frase:\n')
n = random.randint(1,3)
crip = [chr(ord(x)+n) for x in frase]
print(''.join(crip))
# Out:
# Digite a frase:
# Ola mundo
# Qnc"owpfq

# %%
frase = (input('Digite a frase:\n'))
n = random.randint(1,3)
crip = [chr(ord(x)+n) for x in frase]
print(''.join(crip))
# Out:
# Digite a frase:
# Ola mundo
# Rod#pxqgr

# %%
frase = 'Z'
chave = 1
codigo = []

for i in frase:
    if i.isalpha():
        nord = ord(i) + chave
        print(ord(i))
        if nord > 90:
            print(nord)
            nord -= 26
            print(nord)
            codigo.append(chr(nord))
print(''.join(codigo))
# Out:
# 90
# 91
# 65
# A
